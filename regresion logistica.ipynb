# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/home/warrior/Documentos/UNAD/UNAD8/ANALISIS DE DATOS/Guía de actividades y rúbrica de evaluación - Unidad 1 - Etapa 2 - Diseño de sistemas de aprendizaje/Regresion_Logistica.csv",sep=",")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
data[['BMI','glucose']].head()
# Out:
#      BMI  glucose
# 0  26.97     77.0
# 1  28.73     76.0
# 2  25.34     70.0
# 3  28.58    103.0
# 4  23.10     85.0

# %%
data[['BMI','glucose']].plot.scatter(x='BMI',y='glucose')
# Out:
# <Axes: xlabel='BMI', ylabel='glucose'>
